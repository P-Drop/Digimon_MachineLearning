# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset files

# %%
dir = 'dataset/'
file_digimonlist = 'DigiDB_digimonlist.csv'
file_movelist = 'DigiDB_movelist.csv'
file_supportlist = 'DigiDB_supportlist.csv'

# %% [markdown]
# ## Import datasets

# %%
pd.read_csv(dir + file_digimonlist, index_col=0)
# Out:
#                   Digimon Stage     Type Attribute  Memory  Equip Slots  \
# Number
# 1                 Kuramon  Baby     Free   Neutral       2            0
# 2                 Pabumon  Baby     Free   Neutral       2            0
# 3                 Punimon  Baby     Free   Neutral       2            0
# 4                 Botamon  Baby     Free   Neutral       2            0
# 5                 Poyomon  Baby     Free   Neutral       2            0
# ...                   ...   ...      ...       ...     ...          ...
# 245            Valkyrimon  Mega     Free      Wind      18            3
# 246       ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 247     MirageGaogamon BM  Mega     Data     Light      20            2
# 248            Ravemon BM  Mega  Vaccine      Wind      20            2
# 249            Rosemon BM  Mega     Data     Plant      20            2
#
#         Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# Number
# ...

# %%
pd.read_csv(dir + file_movelist)
# Out:
#                 Move  SP Cost      Type  Power Attribute Inheritable  \
# 0      Wolkenapalm I        3  Physical     65      Fire         Yes
# 1     Wolkenapalm II        6  Physical     85      Fire         Yes
# 2    Wolkenapalm III        9  Physical    105      Fire         Yes
# 3      Burst Flame I        3     Magic     55      Fire         Yes
# 4     Burst Flame II        6     Magic     75      Fire         Yes
# ..               ...      ...       ...    ...       ...         ...
# 382  Garuru Tomahawk       20  Physical    140   Neutral          No
# 383   Fist of Athena       50  Physical      0      Fire          No
# 384   Supreme Cannon       30     Magic    130     Water          No
# 385  Dark Prominence       30     Magic      0      Dark          No
# 386     Plasma Shoot       25  Physical     35      Fire          No
#
#                                            Description
# 0    Physical attack, 65 Fire damage to one foe. 95...
# ...

# %%
pd.read_csv(dir + file_supportlist)
# Out:
#                     Name                                        Description
# 0          Adroit Wisdom                              Increases INT by 15%.
# 1            All-Rounder             Increases ATK, DEF, INT and SPD by 5%.
# 2                Analyze                      Increases scan values by 10%.
# 3       Animal Colosseum         Increases damage from Earth skills by 15%.
# 4           Aus Generics  Increases SPD and EVA by 25% when HP drops bel...
# ..                   ...                                                ...
# 81     Unmatched Cruelty  Increases damage from attributes with good aff...
# 82  Unstable Singularity  Increases damage given by 30%, but also increa...
# 83        Wind Guardians          Increases damage from Wind skills by 15%.
# 84                 Wrath  Raises ATK and INT by 25% when HP drops below ...
# 85                Wyvern  Increases damage from Fire and Wind skills by ...
#
# [86 rows x 2 columns]
